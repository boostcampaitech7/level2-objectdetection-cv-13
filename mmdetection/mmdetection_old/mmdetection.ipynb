# %%
# !python mmdetection_cv13.py --mode train --config ssd/ssd512_coco
# !python mmdetection_cv13.py --mode train --config swin/retinanet_swin-t-p4-w7_fpn_1x_coco
# !python mmdetection_cv13.py --mode train --config retinanet/retinanet_x101_32x4d_fpn_1x_coco
# Out:
# /opt/conda/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# config path: ./configs/cascade_rcnn/cascade_rcnn_r50_fpn_1x_coco.py
# work_dir path: ./work_dirs/cascade_rcnn_cascade_rcnn_r50_fpn_1x_coco
# loading annotations into memory...
# Done (t=0.21s)
# creating index...
# index created!
# dataset built!
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# wandb init done!
# ...

# %%
# !python train_cv13.py configs/cv13/faster-rcnn_r50_fpn_fcos-rpn_1x_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# faster-rcnn_r50_fpn_fcos-rpn_1x_coco
# wandb init done!
# 10/17 19:58:12 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 980561010
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

# %%
# !python train_cv13.py configs/cv13/tood_r50_fpn_1x_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# tood_r50_fpn_1x_coco
# wandb init done!
# 10/17 20:29:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1576953908
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...

# %%
# !python train_cv13.py configs/cv13/efficientdet_effb0_bifpn_8xb16-crop512-300e_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# efficientdet_effb0_bifpn_8xb16-crop512-300e_coco
# wandb init done!
# 10/17 20:49:24 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 808470911
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

# %%
# !python train_cv13.py configs/cv13/centernet-update_r101_fpn_8xb8-amp-lsj-200e_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# centernet-update_r101_fpn_8xb8-amp-lsj-200e_coco
# wandb init done!
# 10/17 22:01:55 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1798804816
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

# %%
# !python train_cv13.py configs/cv13/atss_r101_fpn_1x_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# atss_r101_fpn_1x_coco
# wandb init done!
# 10/17 22:25:19 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1101183407
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...

# %%
# !python train_cv13.py configs/cv13/diffusiondet_r50_fpn_500.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# diffusiondet_r50_fpn_500
# wandb init done!
# 10/17 22:45:45 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1056624107
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...

# %%
# !python train_cv13.py configs/cv13/detectors_cascade-rcnn_r50_1x_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# detectors_cascade-rcnn_r50_1x_coco
# wandb init done!
# 10/18 01:32:31 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 648980173
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

# %%
# !python train_cv13.py configs/cv13/dino-4scale_r50_8xb2-12e_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# dino-4scale_r50_8xb2-12e_coco
# wandb init done!
# 10/18 02:55:29 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1619106255
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

# %%
# !python train_cv13.py configs/cv13/gfl_r50_fpn_1x_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# gfl_r50_fpn_1x_coco
# wandb init done!
# 10/18 14:27:34 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 462626483
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...

# %%
# !python train_cv13.py configs/cv13/detectors_cascade-rcnn_r101_1x_coco.py
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# detectors_cascade-rcnn_r101_1x_coco
# wandb init done!
# 10/18 10:44:16 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1841954854
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
# ...

# %%
# !python train_cv13.py configs/cv13/universenet101_2008d_fp16.py


#mmcv 관련 논의 필요 https://eehoeskrap.tistory.com/768
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: superl3 (superl3-naver). Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /data/ephemeral/home/.netrc
# universenet101_2008d_fp16
# wandb init done!
# 10/18 14:49:05 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1712824416
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

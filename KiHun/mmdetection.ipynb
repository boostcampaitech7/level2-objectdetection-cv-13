# %%
# !python mmdetection_cv13.py --mode train --config faster_rcnn/faster_rcnn_r50_fpn_1x_coco
# Out:
# /opt/conda/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# config path: ./configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py
# work_dir path: ./work_dirs/faster_rcnn_faster_rcnn_r50_fpn_1x_coco
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# dataset built!
# 2024-10-15 15:27:59,998 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2024-10-15 15:27:59,998 - mmcv - INFO - load model from: torchvision://resnet50
# 2024-10-15 15:27:59,998 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# ...
